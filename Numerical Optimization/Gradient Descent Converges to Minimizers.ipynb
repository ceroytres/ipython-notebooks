# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.linspace(-2,2,100)

X,Y = np.meshgrid(n,n)
F = .5*X**2+.25*Y**4-.5*Y**2



while True



plt.figure()
plt.contour(X,Y,F,50)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()
